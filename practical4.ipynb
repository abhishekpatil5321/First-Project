# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekpatil5321/First-Project/blob/main/practical4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
j = int(input("ENter a Number : "))

for i in range(1,10+1):
  print(f"{j} x {i} = {i*j}")

# %%
for i in range(1,10+1):
  if i%2==0:
    print(i)

# %%
#print of n numbers

sum = 0
i = 0
j = int(input("Enter a Number : "))


while i<=j:
  sum = sum + i
  i = i+1

print(sum)

# %%
#print of fact of n numbers

fact = 1
i = 1
j = int(input("Enter a Number : "))


while i<=j:
  fact = fact * i
  i = i+1

print(fact)

# %%
#take a number n as input find sum of it digits using while loop

sum = 0
num = int(input("Enter a Number : "))

temp = number

while temp > 0:
  digit = temp % 10
  sum += digit
  temp = temp

print(f"The sum of digits of {number} is: {sum_of_digits}")
# Out:
# Enter a Number : 123
